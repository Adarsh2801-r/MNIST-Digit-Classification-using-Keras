# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow import keras

# %%
(X_train,y_train),(X_test,y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
X_train.shape , y_train.shape
# Out:
# ((60000, 28, 28), (60000,))

# %%
for i in range(0,9):
  plt.subplot(330 + (i+1))
  plt.imshow(X_train[i])
  plt.title(y_train[i])

# %%
X_train = X_train.reshape(X_train.shape[0],-1)
X_test = X_test.reshape(X_test.shape[0],-1)
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")
X_train.shape,X_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
y_train = tf.keras.utils.to_categorical(y_train,10)
y_test = tf.keras.utils.to_categorical(y_test,10)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
scaler.fit(X_test)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(128,activation='relu',input_shape=(784,)))
model.add(tf.keras.layers.Dense(64,activation='relu'))
model.add(tf.keras.layers.Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
keras_history = model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 1.7124 - accuracy: 0.8741 - val_loss: 0.3730 - val_accuracy: 0.9183
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2765 - accuracy: 0.9333 - val_loss: 0.2407 - val_accuracy: 0.9415
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1842 - accuracy: 0.9494 - val_loss: 0.1898 - val_accuracy: 0.9479
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1511 - accuracy: 0.9572 - val_loss: 0.1804 - val_accuracy: 0.9464
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1326 - accuracy: 0.9624 - val_loss: 0.1325 - val_accuracy: 0.9644
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1134 - accuracy: 0.9682 - val_loss: 0.1435 - val_accuracy: 0.9641
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1043 - accuracy: 0.9705 - val_loss: 0.1325 - val_accuracy: 0.9655
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0962 - accuracy: 0.9734 - val_loss: 0.1434 - val_accuracy: 0.9662
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0903 - accuracy: 0.9751 - val_loss: 0.1520 - val_accuracy: 0.9661
# Epoch 10/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0845 - accuracy: 0.9769 - val_loss: 0.1317 - val_accuracy: 0.9668

# %%
model.evaluate(X_test,y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1317 - accuracy: 0.9668
# [0.13165049254894257, 0.9667999744415283]

# %%
plt.imshow(X_test[780].reshape(28,28))
pred = model.predict_classes(X_test[780].reshape(1,784))
plt.title(pred[0])
# Out:
# Text(0.5, 1.0, '3')
